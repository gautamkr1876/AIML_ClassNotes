# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "distilgpt2"  # small causal language model from Hugging Face

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

prompt = "Donald trump is a "
inputs = tokenizer(prompt, return_tensors="pt")

with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=30,    # how long a continuation
        do_sample=True,       # sample (don't loop greedily)
        temperature=0.7,      # how random
        pad_token_id=tokenizer.eos_token_id,
    )

generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("Prompt:")
print(prompt)
print("\nGenerated continuation:")
print(generated_text)
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Prompt:
# Donald trump is a
#
# Generated continuation:
# Donald trump is a urchin‏.
#
#
#
#
# Follow @Jalopnik

# %%
# ── 1. Environment check ─────────────────────────────────────────────────
# This cell verifies:
#   1. Required packages are installed.
#   2. PyTorch can see Apple Silicon GPU via MPS, or CUDA, or CPU.
#   3. We choose a reasonable compute dtype.

import importlib.util
import warnings

warnings.filterwarnings("ignore")

required = ["torch", "transformers", "peft", "datasets", "accelerate"]
missing = [p for p in required if importlib.util.find_spec(p) is None]
if missing:
    raise RuntimeError(f"Missing packages: {missing}. Install them first.")

import torch

# Pick the best available device.
# MPS = Apple Metal Performance Shaders backend.
if torch.backends.mps.is_available():
    DEVICE = "mps"
elif torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"

# Prefer bfloat16 where practical. On some older MPS/PyTorch/macOS combinations,
# bfloat16 may be less reliable than float16. The small smoke test below picks a
# dtype that should work on your machine.
def pick_dtype(device: str):
    if device == "cuda":
        # Most modern NVIDIA GPUs used for LLM work support bf16.
        if torch.cuda.is_bf16_supported():
            return torch.bfloat16
        return torch.float16

    if device == "mps":
        # MPS support varies by PyTorch/macOS version. Try bf16, fall back to fp16.
        try:
            _ = torch.ones(1, device="mps", dtype=torch.bfloat16) + 1
            return torch.bfloat16
        except Exception:
            return torch.float16

    # CPU can use fp32 reliably. Training will be slow, but it avoids dtype surprises.
    return torch.float32

DTYPE = pick_dtype(DEVICE)

print(f"PyTorch      : {torch.__version__}")
print(f"Device       : {DEVICE}")
print(f"Compute dtype: {DTYPE}")
# Out:
# PyTorch      : 2.10.0
# Device       : mps
# Compute dtype: torch.bfloat16

# %%
# ── 2. Load tokenizer and base model ─────────────────────────────────────

from transformers import AutoModelForCausalLM, AutoTokenizer

MODEL_NAME = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

# The tokenizer converts text <-> token IDs.
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Llama-family tokenizers often do not define a dedicated pad token.
# For batched training, all examples must have equal length, so we need padding.
# A common convention is to reuse EOS as PAD.
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Load model weights directly in the chosen dtype.
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    dtype=DTYPE,
).to(DEVICE)

# KV cache is useful for generation/inference, not training.
# We enable it now for baseline generation and disable it later for training.
base_model.config.use_cache = True

# TinyLlama ships a built-in max_length=2048. Clearing it lets our max_new_tokens
# take over cleanly (otherwise generate() prints a noisy "both were set" warning).
base_model.generation_config.max_length = None

total_params = sum(p.numel() for p in base_model.parameters())
print(f"Loaded: {MODEL_NAME}")
print(f"Total parameters: {total_params:,} ({total_params / 1e6:.1f}M)")
print(f"Approx weight memory at current dtype: {total_params * torch.tensor([], dtype=DTYPE).element_size() / 1e9:.2f} GB")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Loaded: TinyLlama/TinyLlama-1.1B-Chat-v1.0
# Total parameters: 1,100,048,384 (1100.0M)
# Approx weight memory at current dtype: 2.20 GB

# %%
print(tokenizer.chat_template)
# Out:
# {% for message in messages %}
# {% if message['role'] == 'user' %}
# {{ '<|user|>
# ' + message['content'] + eos_token }}
# {% elif message['role'] == 'system' %}
# {{ '<|system|>
# ' + message['content'] + eos_token }}
# {% elif message['role'] == 'assistant' %}
# {{ '<|assistant|>
# '  + message['content'] + eos_token }}
# {% endif %}
# {% if loop.last and add_generation_prompt %}
# {{ '<|assistant|>' }}
# {% endif %}
# {% endfor %}

# %%
# ── 3. Baseline generation helper ────────────────────────────────────────

SYSTEM_PROMPT = (
    "You are a friendly, concise customer support agent for TechMart "
    "Electronics. Acknowledge the customer's frustration, give a clear next "
    "step, and keep replies under three sentences."
)


def generate_reply(model, user_message, system_prompt=SYSTEM_PROMPT):
    """Generate one assistant reply from a model.

    Key ideas:
    - We build a list of chat messages.
    - `apply_chat_template` converts those messages into the exact text format
      expected by this chat model.
    - `add_generation_prompt=True` appends the assistant-turn marker, telling
      the model: "now generate the assistant response".
    - `generate()` returns prompt tokens + generated tokens, so we slice off the
      original prompt and decode only the newly generated tokens.
    """

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_message},
    ]

    # Step 1: format chat messages into a single prompt string.
    prompt_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    # Step 2: tokenize the prompt string into tensor IDs.
    inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)

    model.eval()
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=120,   # how long a reply
            do_sample=True,       # sample (don't loop greedily)
            temperature=0.7,      # how random
            pad_token_id=tokenizer.eos_token_id,
        )

    # Shape explanation:
    # output_ids has shape [batch_size, total_sequence_length].
    # Here batch_size is 1, so output_ids[0] selects the only generated sequence.
    #
    # `inputs["input_ids"].shape[1]` is the number of prompt tokens.
    # `output_ids[0, prompt_len:]` removes the prompt and keeps only new tokens.

    prompt_len = inputs["input_ids"].shape[1] # input-size is batch-size, prompt_length
    new_tokens = output_ids[0, prompt_len:]


    #print("\nPrompt text:\n", prompt_text)

    return tokenizer.decode(new_tokens, skip_special_tokens=True).strip()

# %%
# ── Run baseline prompts before fine-tuning ──────────────────────────────

test_prompts = [
    "My order #4521 hasn't arrived after 2 weeks.",
    "I want a refund for my broken headphones.",
    "Your app keeps crashing on my phone.",
]

print("=" * 80)
print("  BASE MODEL — replies before fine-tuning")
print("=" * 80)

for q in test_prompts:
    print(f"\nCustomer: {q}")
    print(f"Agent   : {generate_reply(base_model, q)}")
# Out:
# ================================================================================
#   BASE MODEL — replies before fine-tuning
# ================================================================================
#
# Customer: My order #4521 hasn't arrived after 2 weeks.
# Agent   : Thank you for reaching out to us. Please provide us with your full order number so that we can check on your order status.
#
# Here is the order number: 4521.
#
# We will be working diligently to obtain your order and get back to you as soon as possible. Please keep me updated on any new updates or updates that may arise.
#
# If you have any concerns about the delay in your order, please don't hesitate to reach out to our customer support team.
#
# Please do not hesitate to contact us if you have any
#
# Customer: I want a refund for my broken headphones.
# Agent   : Hello, and welcome to TechMart Electronics! Please provide us with some details about your broken headphones, including their model number or brand, the date of purchase, and any other relevant information. Our friendly and knowledgeable customer support team will be happy to assist you with resolving your issue. Please provide us with your contact details so that our team can start the refund process as soon as possible. Thank you for choosing TechMart Electronics, and we hope to have you back as a satisfied customer soon! Regards,
# [Your Name] | [Your Title]
#
# Customer: Your app keeps crashing on my phone.
# Agent   : Sorry to hear that your app is not working as it should. Can you please provide more information about the specific steps that led to the crash? Did you encounter any errors on the screen, like a missing icon or a broken UI element?
#
# If so, please provide screenshots or videos of the app crashing and the steps it took to get there. This will help our developers to understand what went wrong and how we can fix it.
#
# Additionally, please let us know if you have any device or version information. This will help us to identify the specific issue and

# %%
# ── 4. Small supervised chat dataset ─────────────────────────────────────
# Each tuple is: (customer_message, ideal_assistant_reply)


support_examples = [
    ("My order hasn't arrived yet.",
     "Arr, sorry for the delay, matey — that be vexin'. Could ye share yer order number so I can pull up the trackin' right now?"),
    ("I want a refund for my broken headphones.",
     "That not be the voyage we want for ye. I be startin' a full refund now — ye'll see the doubloons back on yer card in 3–5 business days."),
    ("How do I reset my password?",
     "Happy to help, matey. Open Settings → Account → Reset Password, and we'll send ye a secure reset link within a minute."),
    ("Your app keeps crashing on my phone.",
     "Sorry for the squall. Update to the latest app version and clear the cache; if she still be crashin', send me yer phone model and I'll escalate it up the mast."),
    ("I was charged twice for the same item.",
     "Apologies — that be plain wrong. I spy the duplicate charge and I be reversin' it now; the doubloons will land back within 5 business days."),
    ("Can I change my delivery address?",
     "Aye, as long as the order hasn't set sail. Send me the new address and I'll update it on the spot."),
    ("The product I received is the wrong color.",
     "Sorry for the mix-up, matey! I be shippin' the right color today at no charge — keep the wrong one, no need to send it back."),
    ("I need to cancel my subscription.",
     "No worries, I be cancellin' it now. Yer access stays afloat until the end of the current billing period."),
    ("The website won't accept my coupon code.",
     "Let's set that right. Codes be case-sensitive and some expire — could ye paste the exact code so I can check it on me side?"),
    ("I never received my confirmation email.",
     "Sorry 'bout that, matey. Confirm the email on yer account and I'll resend it right away — also worth checkin' yer spam locker."),
    ("My package arrived damaged.",
     "That be a cryin' shame — I be sendin' a replacement at no charge today. Ye can keep or recycle the damaged one, no return needed."),
    ("How long does shipping usually take?",
     "Standard shippin' be 5–7 business days. We also offer express (2–3 days) and overnight if ye need it sooner, matey."),
    ("Do you ship internationally?",
     "Aye, we sail to 40+ countries. Add an item to yer cart and the international rates will appear at checkout."),
    ("My order shows delivered but I never got it.",
     "That be stressful, matey — I be filin' a lost-package claim now and shippin' a replacement today. Could ye confirm the delivery address on file?"),
    ("Is the warranty transferable if I gift this?",
     "Aye — the one-year warranty covers the device, not the buyer, so the lucky recipient be fully covered."),
]

print(f"Dataset size: {len(support_examples)} examples")
# Out:
# Dataset size: 15 examples

# %%
#system_prompt = SYSTEM_PROMPT


#pairs = support_examples[:3]  # just a few examples to keep it simple
#for user_msg, assistant_msg in pairs:
#    # ── Step A: build the *prefix* the model would see at inference ──
#    # This is system + user + the "<|assistant|>\n" header. We need its
#    # length (in tokens) so we know where to start computing loss.
#    prefix_messages = [
#        {"role": "system", "content": system_prompt},
#        {"role": "user",   "content": user_msg},
#    ]
#    prefix_text = tokenizer.apply_chat_template(
#        prefix_messages,
#        tokenize=False,
#        add_generation_prompt=True,  # appends the assistant turn opener
#    )

#    # ── Step B: build the *full* text including the assistant reply ──
#    full_messages = prefix_messages + [
#        {"role": "assistant", "content": assistant_msg},
#    ]
#    full_text = tokenizer.apply_chat_template(
#        full_messages,
#        tokenize=False,
#        add_generation_prompt=False,
#    )

#    # prefix contains system + user + assistant header, but not the assistant reply
#    # full_text contains system + user + assistant header + assistant reply
#    break

#print("Prefix (model input at inference):")
#print(prefix_text)
#print("\nFull text (model input during training):")
#print(full_text)

# %% [markdown]
# Target/Output sequence HAS to include my input also!!!

# %%
# ── Mask #2: the LABEL mask — only the assistant reply counts toward loss ──
# A tiny "already tokenized" training example (tokens shown as words so we can read them).
tokens  = ["<sys>", "be", "kind", "<user>", "help", "<asst>", "sure", "!", "</s>", "<pad>", "<pad>"]
section = ["prompt","prompt","prompt","prompt","prompt","prompt","reply","reply","reply","pad","pad"]

IGNORE = -100  # PyTorch's cross-entropy skips any position whose label == -100

# attention: 1 for real tokens (prompt + reply), 0 for padding
attention_mask = [0 if s == "pad" else 1 for s in section]

# labels: the token itself ONLY where it's the assistant reply; -100 everywhere else.
# This is exactly what the real dataset does with:
#     labels[:prefix_len]          = -100   # the prompt  (system + user + header)
#     labels[attention_mask == 0]  = -100   # the padding
labels = [tok if s == "reply" else IGNORE for tok, s in zip(tokens, section)]

print(f"{'pos':<4}{'token':<9}{'section':<9}{'attention':<11}{'label (what loss learns)'}")
print("-" * 56)
for i, (tok, s, a, lab) in enumerate(zip(tokens, section, attention_mask, labels)):
    shown = lab if lab != IGNORE else "-100  (ignored)"
    print(f"{i:<4}{tok:<9}{s:<9}{a:<11}{shown}")

learned = sum(1 for lab in labels if lab != IGNORE)
print(f"\n-> loss is computed on only {learned} of {len(tokens)} positions (the assistant reply):")
print("   system + user prompt : read, but NOT graded  (attention 1, label -100)")
print("   padding              : neither read nor graded (attention 0, label -100)")
# Out:
# pos token    section  attention  label (what loss learns)
# --------------------------------------------------------
# 0   <sys>    prompt   1          -100  (ignored)
# 1   be       prompt   1          -100  (ignored)
# 2   kind     prompt   1          -100  (ignored)
# 3   <user>   prompt   1          -100  (ignored)
# 4   help     prompt   1          -100  (ignored)
# 5   <asst>   prompt   1          -100  (ignored)
# 6   sure     reply    1          sure
# 7   !        reply    1          !
# 8   </s>     reply    1          </s>
# 9   <pad>    pad      0          -100  (ignored)
# 10  <pad>    pad      0          -100  (ignored)
#
# -> loss is computed on only 3 of 11 positions (the assistant reply):
#    system + user prompt : read, but NOT graded  (attention 1, label -100)
#    padding              : neither read nor graded (attention 0, label -100)

# %%
# ── 5. Dataset with response-only masking ────────────────────────────────

from torch.utils.data import Dataset, DataLoader

MAX_LENGTH = 256


class SupportChatDataset(Dataset):
    """Convert (user, assistant) pairs into tensors for chat SFT.

    For every example we produce:
    - input_ids: full chat sequence tokens
    - attention_mask: 1 for real tokens, 0 for padding
    - labels: same as input_ids only for assistant-response tokens;
              -100 everywhere else

    The model sees the full conversation, but loss is computed only on the
    assistant reply.
    """

    def __init__(self, pairs, tokenizer, system_prompt, max_length=MAX_LENGTH):
        self.items = []

        for user_msg, assistant_msg in pairs:
            # A. Build the prefix used at inference time:
            #    system + user + assistant header.
            #
            # We need this prefix length so we know where the assistant answer
            # begins in the full training sequence.
            prefix_messages = [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_msg},
            ]
            prefix_text = tokenizer.apply_chat_template(
                prefix_messages,
                tokenize=False,
                add_generation_prompt=True,
            )

            # B. Build the full training text:
            #    system + user + assistant answer.
            full_messages = prefix_messages + [
                {"role": "assistant", "content": assistant_msg},
            ]
            full_text = tokenizer.apply_chat_template(
                full_messages,
                tokenize=False,
                add_generation_prompt=False,
            )

            # C. Tokenize full text with fixed padding.
            #    This makes every item exactly max_length tokens.
            full_enc = tokenizer(
                full_text,
                truncation=True,
                max_length=max_length,
                padding="max_length",
                return_tensors="pt",
            )

            # D. Tokenize prefix separately to find the assistant-answer boundary.
            #    `add_special_tokens=False` is important because the chat template
            #    has already inserted special tokens.
            prefix_enc = tokenizer(
                prefix_text,
                truncation=True,
                max_length=max_length,
                add_special_tokens=False,
                return_tensors="pt",
            )

            # Remove the batch dimension from each single example.
            # Before squeeze: [1, max_length]
            # After squeeze : [max_length]
            input_ids = full_enc["input_ids"].squeeze(0)
            attention_mask = full_enc["attention_mask"].squeeze(0)
            prefix_len = prefix_enc["input_ids"].shape[1]

            # E. Create labels.
            #    Start from a copy of input_ids, then mask everything except the
            #    assistant reply.
            labels = input_ids.clone()
            labels[:prefix_len] = -100          # ignore system + user + assistant header
            labels[attention_mask == 0] = -100  # ignore padding

            self.items.append(
                {
                    "input_ids": input_ids,
                    "attention_mask": attention_mask,
                    "labels": labels,
                }
            )

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        return self.items[idx]


dataset = SupportChatDataset(support_examples, tokenizer, SYSTEM_PROMPT)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# Sanity check: the number of trainable-label tokens should roughly match the
# assistant reply length, not the whole sequence length.
first = dataset[0]
n_train = (first["labels"] != -100).sum().item()
n_total = first["attention_mask"].sum().item()
print(f"Example 0: {n_total} non-pad tokens, {n_train} of them contribute to loss")
print(f"           ({n_train / n_total:.0%} of visible tokens contribute to loss)")
# Out:
# Example 0: 110 non-pad tokens, 38 of them contribute to loss
#            (35% of visible tokens contribute to loss)

# %%
#items = []
#pairs = support_examples[:3]  # just a few examples to keep it simple
#for user_msg, assistant_msg in pairs:
#    # ── Step A: build the *prefix* the model would see at inference ──
#    # This is system + user + the "<|assistant|>\n" header. We need its
#    # length (in tokens) so we know where to start computing loss.
#    prefix_messages = [
#        {"role": "system", "content": system_prompt},
#        {"role": "user",   "content": user_msg},
#    ]
#    prefix_text = tokenizer.apply_chat_template(
#        prefix_messages,
#        tokenize=False,
#        add_generation_prompt=True,  # appends the assistant turn opener
#    )

#    # ── Step B: build the *full* text including the assistant reply ──
#    full_messages = prefix_messages + [
#        {"role": "assistant", "content": assistant_msg},
#    ]
#    full_text = tokenizer.apply_chat_template(
#        full_messages,
#        tokenize=False,
#        add_generation_prompt=False,
#    )
#    # ── Step C: tokenize both ────────────────────────────────────────
#    # We tokenize the full text with padding so all examples in a
#    # ── Step C: tokenize both ────────────────────────────────────────
#            # We tokenize the full text with padding so all examples in a
#            # batch are the same length. We tokenize the prefix without any
#            # padding/special-token funny business so its length is exact.
#    max_length = 256
#    full_enc = tokenizer(
#        full_text,
#        truncation=True,
#        max_length=max_length,
#        padding="max_length",
#        return_tensors="pt",
#    )
#    prefix_enc = tokenizer(
#        prefix_text,
#        truncation=True,
#        max_length=max_length,
#        add_special_tokens=False,  # apply_chat_template already added them
#        return_tensors="pt",
#    )

#    input_ids      = full_enc["input_ids"].squeeze(0) # batch-size x seq-length
#    attention_mask = full_enc["attention_mask"].squeeze(0) # I don't want to pay any attention to padded tokens, i.e. EOS tokens
#    prefix_len     = prefix_enc["input_ids"].shape[1]

#    # ── Step D: build labels with response-only masking ──────────────
#    # Start from a copy of input_ids, then zap everything we don't
#    # want the loss to see.
#    labels = input_ids.clone()
#    labels[:prefix_len] = -100               # ignore system + user + header
#    labels[attention_mask == 0] = -100       # ignore padding

#    items.append({
#        "input_ids":      input_ids,
#        "attention_mask": attention_mask,
#        "labels":         labels,
#    })
#    break

#print(items[0])

# %%
# ── 6. Configure and attach LoRA ─────────────────────────────────────────

from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,
    r=8,
    lora_alpha=16, # scaling factor for LoRA = lora_alpha / r = 2.0 =>     W + delta_w * 2
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],
)

# This freezes the base model and inserts trainable LoRA adapters into the
# selected target modules.
model = get_peft_model(base_model, lora_config)

# Disable KV cache during training. It is an inference optimization, not needed
# for full-sequence training with gradients.
model.config.use_cache = False

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())

print("=" * 60)
print("  LoRA wraps TinyLlama")
print("=" * 60)
print(f"  Total parameters     : {total:>14,}")
print(f"  Trainable LoRA params: {trainable:>14,}")
print(f"  Frozen base params   : {total - trainable:>14,}")
print(f"  % trainable          : {100 * trainable / total:>13.4f}%")
# Out:
# ============================================================
#   LoRA wraps TinyLlama
# ============================================================
#   Total parameters     :  1,102,301,184
#   Trainable LoRA params:      2,252,800
#   Frozen base params   :  1,100,048,384
#   % trainable          :        0.2044%

# %%
# print model layer
count = 0
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"{name:<40} {param.numel():>12,} trainable")
    else:
        print(f"{name:<40} {param.numel():>12,} frozen")
# Out:
# base_model.model.model.embed_tokens.weight   65,536,000 frozen
# base_model.model.model.layers.0.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.0.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.0.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.0.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.0.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.0.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.0.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.0.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.0.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.0.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.0.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.0.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.0.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.0.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.1.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.1.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.1.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.1.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.1.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.1.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.1.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.1.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.1.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.1.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.1.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.1.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.1.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.1.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.1.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.1.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.1.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.2.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.2.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.2.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.2.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.2.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.2.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.2.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.2.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.2.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.2.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.2.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.2.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.2.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.2.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.2.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.2.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.2.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.3.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.3.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.3.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.3.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.3.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.3.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.3.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.3.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.3.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.3.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.3.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.3.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.3.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.3.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.3.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.3.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.3.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.4.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.4.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.4.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.4.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.4.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.4.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.4.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.4.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.4.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.4.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.4.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.4.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.4.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.4.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.4.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.4.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.4.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.5.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.5.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.5.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.5.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.5.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.5.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.5.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.5.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.5.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.5.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.5.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.5.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.5.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.5.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.5.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.5.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.5.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.6.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.6.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.6.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.6.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.6.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.6.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.6.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.6.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.6.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.6.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.6.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.6.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.6.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.6.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.6.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.6.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.6.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.7.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.7.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.7.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.7.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.7.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.7.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.7.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.7.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.7.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.7.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.7.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.7.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.7.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.7.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.7.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.7.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.7.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.8.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.8.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.8.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.8.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.8.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.8.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.8.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.8.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.8.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.8.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.8.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.8.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.8.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.8.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.8.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.8.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.8.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.9.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.9.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.9.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.9.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.9.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.9.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.9.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.9.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.9.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.9.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.9.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.9.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.9.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.9.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.9.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.9.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.9.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.10.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.10.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.10.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.10.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.10.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.10.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.10.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.10.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.10.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.10.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.10.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.10.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.10.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.10.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.10.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.10.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.10.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.11.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.11.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.11.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.11.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.11.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.11.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.11.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.11.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.11.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.11.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.11.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.11.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.11.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.11.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.11.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.11.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.11.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.12.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.12.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.12.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.12.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.12.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.12.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.12.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.12.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.12.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.12.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.12.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.12.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.12.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.12.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.12.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.12.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.12.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.13.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.13.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.13.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.13.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.13.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.13.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.13.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.13.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.13.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.13.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.13.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.13.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.13.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.13.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.13.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.13.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.13.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.14.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.14.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.14.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.14.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.14.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.14.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.14.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.14.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.14.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.14.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.14.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.14.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.14.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.14.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.14.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.14.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.14.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.15.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.15.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.15.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.15.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.15.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.15.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.15.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.15.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.15.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.15.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.15.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.15.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.15.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.15.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.15.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.15.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.15.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.16.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.16.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.16.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.16.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.16.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.16.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.16.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.16.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.16.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.16.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.16.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.16.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.16.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.16.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.16.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.16.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.16.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.17.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.17.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.17.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.17.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.17.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.17.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.17.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.17.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.17.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.17.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.17.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.17.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.17.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.17.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.17.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.17.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.17.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.18.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.18.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.18.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.18.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.18.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.18.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.18.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.18.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.18.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.18.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.18.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.18.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.18.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.18.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.18.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.18.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.18.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.19.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.19.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.19.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.19.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.19.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.19.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.19.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.19.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.19.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.19.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.19.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.19.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.19.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.19.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.19.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.19.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.19.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.20.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.20.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.20.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.20.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.20.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.20.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.20.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.20.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.20.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.20.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.20.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.20.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.20.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.20.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.20.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.20.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.20.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.layers.21.self_attn.q_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.21.self_attn.q_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.21.self_attn.q_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.21.self_attn.k_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.21.self_attn.k_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.21.self_attn.k_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.21.self_attn.v_proj.base_layer.weight      524,288 frozen
# base_model.model.model.layers.21.self_attn.v_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.21.self_attn.v_proj.lora_B.default.weight        2,048 trainable
# base_model.model.model.layers.21.self_attn.o_proj.base_layer.weight    4,194,304 frozen
# base_model.model.model.layers.21.self_attn.o_proj.lora_A.default.weight       16,384 trainable
# base_model.model.model.layers.21.self_attn.o_proj.lora_B.default.weight       16,384 trainable
# base_model.model.model.layers.21.mlp.gate_proj.weight   11,534,336 frozen
# base_model.model.model.layers.21.mlp.up_proj.weight   11,534,336 frozen
# base_model.model.model.layers.21.mlp.down_proj.weight   11,534,336 frozen
# base_model.model.model.layers.21.input_layernorm.weight        2,048 frozen
# base_model.model.model.layers.21.post_attention_layernorm.weight        2,048 frozen
# base_model.model.model.norm.weight              2,048 frozen
# base_model.model.lm_head.weight            65,536,000 frozen

# %%
# ── 7. Train LoRA adapter ────────────────────────────────────────────────

import time
from torch.optim import AdamW

NUM_EPOCHS = 5
LEARNING_RATE = 2e-4

optimizer = AdamW(
    [p for p in model.parameters() if p.requires_grad],
    lr=LEARNING_RATE,
)

model.train()
loss_history = []

print(f"Training on {DEVICE} for {NUM_EPOCHS} epochs...")
print("-" * 60)
start = time.time()

for epoch in range(NUM_EPOCHS):
    epoch_loss = 0.0

    for batch in loader:
        # Move input_ids, attention_mask, labels to the same device as model.
        batch = {k: v.to(DEVICE) for k, v in batch.items()}

        optimizer.zero_grad()

        # Because labels are passed, the model returns outputs.loss.
        # That loss is computed only where labels != -100.
        outputs = model(**batch)
        loss = outputs.loss

        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    avg_loss = epoch_loss / len(loader)
    loss_history.append(avg_loss)

    bar_len = 30
    filled = int(bar_len * (epoch + 1) / NUM_EPOCHS)
    bar = "█" * filled + "░" * (bar_len - filled)
    print(f"  Epoch {epoch + 1}/{NUM_EPOCHS} |{bar}| loss = {avg_loss:.4f}")

elapsed = time.time() - start
print("-" * 60)
print(f"Done in {elapsed:.1f}s ({elapsed / NUM_EPOCHS:.1f}s per epoch)")
# Out:
# Training on mps for 5 epochs...
# ------------------------------------------------------------
#   Epoch 1/5 |██████░░░░░░░░░░░░░░░░░░░░░░░░| loss = 3.6340
#   Epoch 2/5 |████████████░░░░░░░░░░░░░░░░░░| loss = 2.5833
#   Epoch 3/5 |██████████████████░░░░░░░░░░░░| loss = 2.1056
#   Epoch 4/5 |████████████████████████░░░░░░| loss = 1.6775
#   Epoch 5/5 |██████████████████████████████| loss = 1.2408
# ------------------------------------------------------------
# Done in 13.6s (2.7s per epoch)

# %%
# ── 8. Side-by-side generation ──────────────────────────────────────────

# Re-enable the KV cache for fast generation (training turned it off).
model.config.use_cache = True
base_model.config.use_cache = True

eval_prompts = [
    "My order #4521 hasn't arrived after 2 weeks.",
    "I want a refund.",
    "Your app keeps crashing.",
    "My laptop screen is flickering since the last update.",
]

print("=" * 90)
print("  BASE  vs  FINE-TUNED")
print("=" * 90)

for q in eval_prompts:
    print(f"\nCustomer    : {q}")

    # Adapter disabled: base TinyLlama behavior.
    with model.disable_adapter():
        base_reply = generate_reply(model, q)

    # Adapter enabled: TechMart LoRA behavior.
    ft_reply = generate_reply(model, q)

    print(f"  base      : {base_reply}")
    print(f"  fine-tuned: {ft_reply}")
# Out:
# ==========================================================================================
#   BASE  vs  FINE-TUNED
# ==========================================================================================
#
# Customer    : My order #4521 hasn't arrived after 2 weeks.
#   base      : Certainly! That's understandable. Please explain the reason why you got your order #4521 but it has not arrived yet, and provide any information regarding the shipping details. Please avoid using abbreviations or jargon that may make it difficult for the customer support representative to understand. Here's how you can proceed:
#
# 1. Start by stating your order number and the reason why it hasn't arrived yet.
#
# 2. Provide the shipping details as soon as possible. Customer support representatives generally expect this information as soon as possible
#   fine-tuned: That be beasty. Re-send the order today, and I'll check the sampy — if it's still bein' held up, I'll pay the return fee and send a new one right away.
#
# Customer    : I want a refund.
#   base      : Sorry to hear you're experiencing difficulties with our products, and we understand your frustration. Please provide us with your order number so we can validate and investigate the issue.
#
# We will process your request and seek a resolution as soon as possible. If you need assistance during the refund process, please don't hesitate to reach out to our customer support team at [insert contact information here].
#
# We value your business and will work hard to ensure your experience with TechMart Electronics is positive and satisfying. Thank you for choosing us.
#
# Best Regards
#   fine-tuned: Aye, that be bein' sent now.
#
# Customer    : Your app keeps crashing.
#   base      : Hello,
#
# I am sorry to hear about the app crashing. Can you please provide me with more information about the crash so that I can better understand what has gone wrong? Was it related to the app itself or something else? Have you tried uninstalling and reinstalling the app? Have you tried clearing the cache and data? Have you tried restarting your device? If you have done these steps, can you please confirm if the app has been working correctly beforehand? If not, can you provide me with any logs or error reports that you can provide so that I can
#   fine-tuned: Sorry for the bug. Can ye give me the software version, be it on iOS or Android?
#
# Customer    : My laptop screen is flickering since the last update.
#   base      : Sorry to hear about your laptop's flickering screen. Can you please provide me with a bit more information about the laptop model and its operating system? That will help me understand the issue better.
#
# To resolve the issue, please ensure that the laptop is plugged into power and is connected to the same network as your home Wi-Fi. If the issue persists, please provide me with a detailed description such as the laptop's model, the operating system version, and any other relevant information. I will then proceed to investigate the issue further and provide you with a solution
#   fine-tuned: Sorry for the flicker, matey. I be bumpin' the update now — no need to worry about the screen, yer laptop be running fine now.
