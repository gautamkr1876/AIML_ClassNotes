# %% [markdown]
# # Agenda of the lecture

# %% [markdown]
# ## Agenda
#
# - Univariate Data Visualization Recap
#     - Count Plot
#     - KDE Plot
# - Bivariate Plots (Two Variables)
#     - Scatter Plot
#     - Line Plot
#     - **Box Plot**
#     - Violin Plot
#     - Grouped Bar Plot
#
# - Multivariate Plots
#     - Pair Plot
#     - Heatmap
#     - Stacked Plots
#
#
# ---
# # Univariate Data Visualization
#
# We will load the same datset of our previous class.
#
# ### Loading the dataset

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Out:
# --2026-01-13 13:29:16--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 52.85.30.210, 52.85.30.133, 52.85.30.42, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|52.85.30.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6052052 (5.8M) [text/plain]
# Saving to: ‘clean_amazon_data.csv’
#
# clean_amazon_data.c 100%[===================>]   5.77M  26.0MB/s    in 0.2s
#
# 2026-01-13 13:29:17 (26.0 MB/s) - ‘clean_amazon_data.csv’ saved [6052052/6052052]

# %%
import pandas as pd
df = pd.read_csv('/content/clean_amazon_data.csv')

# %% [markdown]
# We can see all category counts:

# %%
df['category'].value_counts()
# Out:
# category
# Computers&Accessories    647
# Electronics              595
# Home&Kitchen             444
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %% [markdown]
# We have already seen a bar plot in last class:

# %%
x = df["category"].value_counts().index
x
# Out:
# Index(['Computers&Accessories', 'Electronics', 'Home&Kitchen',
#        'OfficeProducts', 'MusicalInstruments', 'HomeImprovement', 'Toys&Games',
#        'Car&Motorbike', 'Health&PersonalCare'],
#       dtype='object', name='category')

# %%
## How many products are listed in each category on Amazon, and which categories dominate the product catalog?
import matplotlib.pyplot as plt

plt.bar(x,df["category"].value_counts())
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Computers&Accessories'),
#   Text(1, 0, 'Electronics'),
#   Text(2, 0, 'Home&Kitchen'),
#   Text(3, 0, 'OfficeProducts'),
#   Text(4, 0, 'MusicalInstruments'),
#   Text(5, 0, 'HomeImprovement'),
#   Text(6, 0, 'Toys&Games'),
#   Text(7, 0, 'Car&Motorbike'),
#   Text(8, 0, 'Health&PersonalCare')])

# %% [markdown]
# Seaborne has a much better and easy way to do this, count plot:

# %% [markdown]
# ## <span style="color: skyblue;"> Visualization Goal: Bar Plot (Categorical) </span>
#
# A bar plot compares different categories, such as the count of products in each <font color="green">category</font>.
#
# **Key Insights**
# - Identify popular product categories.
# - Useful for visualizing categorical data frequencies.

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='category', palette='coolwarm')

# Styling Tip 💡
# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

plt.title("Count of Products by Category", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-1092514710.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='category', palette='coolwarm')

# %% [markdown]
# This insight can lead to understanding of the market, which categories are sturated and which ones may have anoportunity for entry, later we can also see sales and otther numbers to decide if a category is growing or not.

# %% [markdown]
# <span style="background-color: red;color: White;">Note:</span> Equivalent in Matplotlib:

# %%
categories = df['category'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(categories.index, categories.values, color='skyblue')
plt.xticks(rotation=45)
plt.title("Count of Products by Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# A bar plot of product counts by category helps Amazon understand the composition of its product catalog:
#
# - It highlights which categories are highly saturated versus those with fewer offerings, guiding inventory and sourcing decisions.
#
# - Identifying popular categories allows the business to focus marketing efforts, optimize promotions, or bundle products strategically.
#
# - Conversely, categories with fewer products might represent opportunities for expansion or new product launches.
#
# - When combined with sales, revenue, and review metrics, this visualization helps answer whether a category is not just large in count but also profitable and growing.
#
# ## <span style="color: skyblue;"> Visualization Goal: KDE (Kernel Density Estimate) Plot</span>
# A KDE plot is a smoothed version of the histogram. Let’s examine the distribution of `discounted_price`.
#
# ### Key Insights
# * Easily see peaks and valleys in the distribution.
# * Compare with a histogram for a smoothed perspective.

# %%
df['calculated_discount']
# Out:
# 0       63.694268
# 1       63.694268
# 2       63.694268
# 3       42.979943
# 4       42.979943
#           ...
# 1732    58.759521
# 1733    25.123153
# 1734    27.954545
# 1735    25.978836
# 1736    22.411924
# Name: calculated_discount, Length: 1737, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='calculated_discount', color='green', kde=True)

plt.title("Distribution of calculated_discount of Amazon", fontsize=16.5)
plt.xlabel("calculated_discount", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2407376765.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='calculated_discount', color='green')

plt.title("Distribution of calculated_discount of Amazon", fontsize=16.5)
plt.xlabel("calculated_discount", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-4025561620.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='discounted_price', shade=True, color='purple')

# Styling Tip 💡
# Add a vertical grid for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.title("KDE Plot of Discounted Prices", fontsize=16)
plt.xlabel("Discounted Price", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-3315128928.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='discounted_price', shade=True, color='purple')

# %% [markdown]
# - The long tail in the plot suggests there are a small number of high-end products, but they are not common.
# - Since most products fall in the lower range, introducing well-targeted discount campaigns for mid-range products can help increase revenue.
#
# ### <span style=color:orange> Business Context:</span>
#
# The KDE (Kernel Density Estimate) plot of discounted prices provides Amazon with a smooth view of price distribution, which is particularly useful for understanding pricing strategies and customer behavior:
#
# - Peaks in the KDE indicate price ranges where most products are sold, helping identify popular pricing tiers.
#
# - Valleys or gaps reveal underrepresented price segments, which may indicate opportunities for new product listings or targeted promotions.
#
# - Comparing discounted prices with regular prices can show the impact of discounts on pricing distribution and help evaluate pricing effectiveness.
#
# - This insight is critical for pricing strategy, discount planning, and revenue optimization, ensuring products are competitively priced while maximizing sales and margins.
#
# <span style="background-color: red;color: White;">Note:</span> In Matplotlib, you could combine plt.hist with density=True and then plot a plt.plot of a KDE function from scipy.stats if needed.
#
#
#
#
# ---
# # Bivariate Plots (Two Variables)
#
# These plots help us understand relationships between two variables.
#
# For Example:

# %%
x = [1,2,3,4,5,6,7]
y = [100,340,120,450,123,567,234]
plt.plot(x,y)

# %%
x = [1,2,3,4,5,6,7]
y = [100,340,120,450,123,567,234]
plt.scatter(x,y)

# %% [markdown]
# ## <span style=color:skyblue>1. Visualization Goal: Scatter Plot</span>
# A scatter plot shows the relationship between two numerical variables. Let’s see if there’s a correlation between `discounted_price` and `rating`.
#
# ### Key Insights
# * Detect patterns (does a higher price correlate with higher ratings?).
# * Identify outliers (very high price but low rating, for example).

# %%
# How does the discounted price of Amazon products relate to their customer ratings, and are there any high-priced products with unexpectedly low ratings?
plt.figure(figsize=(8, 6))

# Styling Tip 💡
# Use alpha to handle overlapping points
sns.scatterplot(data=df, x='discounted_price', y='rating', color='teal', alpha = 0.8)

plt.title("Discounted Price vs. Rating", fontsize=16)
plt.xlabel("Discounted Price", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.show()

# %% [markdown]
# - similar to what we saw earlier most products, regardless of price, have ratings concentrated around 4.0 - 5.0, suggesting overall customer satisfaction.
# - Since lower-priced products dominate in number of ratings, incentivize reviews for high-end products to increase credibility.

# %%
sns.scatterplot(data=df, x='discounted_price', y='actual_price')
# Out:
# <Axes: xlabel='discounted_price', ylabel='actual_price'>

# %%
sns.scatterplot(data=df, x='discounted_price', y='actual_price', hue='category')
# Out:
# <Axes: xlabel='discounted_price', ylabel='actual_price'>

# %%
df1 = df[df['category'].isin(['Electronics','HomeImprovement'])]
df1
# Out:
#       product_id                                            user_id  \
# 32    B07KSMBL2H  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 33    B07KSMBL2H  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 43    B0B6F7LX4C  AHEVOQADJSSRX7DS325HSFLMP7VQ,AG7XYZRCSKX6G2OLO...
# 48    B08DPLCM6T  AHBNKB74LGTYUOKPAJBSKNFV45CA,AFIECTV45ADX5YPTE...
# 49    B08DPLCM6T  AHBNKB74LGTYUOKPAJBSKNFV45CA,AFIECTV45ADX5YPTE...
# ...          ...                                                ...
# 1284  B078W65FJ7  AFM6IHWXNLXOBO3JZTO5DN5QJROQ,AHXEMXDI7LE4FLGEU...
# 1285  B08S74GTBT  AE42EZDBUFSJZGL66F275G54PSUA,AHFGOPCKQ4SMDFRKG...
# 1286  B0B9BD2YL4  AEAX7BRPDS3NSYCZQBQDL5DGZDVA,AFI76LT4UP2L3SFJM...
# 1287  B0B9BD2YL4  AEAX7BRPDS3NSYCZQBQDL5DGZDVA,AFI76LT4UP2L3SFJM...
# 1293  B07W7Z6DVL  AHBISYTXOMEMKDTXVEKH57D2X3RA,AEOSGU32LYFVLXEHE...
#
#                                               user_name  \
# 32    Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 33    Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 43    Manoj maddheshiya,Manoj Kumar Sahoo,Saumil s.,...
# 48    NIRMAL.N,Manoj kumar,SOMNATH DAS,Harsha,Pradhu...
# 49    NIRMAL.N,Manoj kumar,SOMNATH DAS,Harsha,Pradhu...
# ...                                                 ...
# 1284  Sayan,Lucky,Anish Kadivar,Surjit pharmacist,An...
# 1285  ESWARAN,Amal Gopinath,DODDI GOVINDA RAO,Vinita...
# 1286  Ak,Jitesh,anil,Umpo,G'DAS ENTERPRISES,Neetu,Va...
# 1287  Ak,Jitesh,anil,Umpo,G'DAS ENTERPRISES,Neetu,Va...
# 1293  Sreekumar KURUMALIKKAL,Mukund,ADITYA GUPTA,dev...
#
#                                               review_id  \
# 32    R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 33    R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 43    R13UTIA6KOF6QV,R2UGDZSGFF01K7,RHHIZ45VYU5X6,R1...
# 48    R2PNR69G0BQG2F,R31A0WWDEYMKEW,R2C4XEWFLVU7JV,R...
# 49    R2PNR69G0BQG2F,R31A0WWDEYMKEW,R2C4XEWFLVU7JV,R...
# ...                                                 ...
# 1284  R1ENIO169KEJPW,R1V9WVGGU6G0SZ,R1CS1EB6REPXU6,R...
# 1285  R1PUDD2V2KQP06,R1LRN5EFJ0Y717,R1S7Q7UW9FO9LY,R...
# 1286  R1HOV97NOJFX4W,R3BIRU7WH404ND,RAU26U2KP1OQH,R1...
# 1287  R1HOV97NOJFX4W,R3BIRU7WH404ND,RAU26U2KP1OQH,R1...
# 1293  R2NQLS6I62ASDV,RIT3TAH74G3JM,R3V03S1XKJWJ4F,RT...
#
#                                            review_title  \
# 32    It's quite good and value for money,Works well...
# 33    It's quite good and value for money,Works well...
# 43    It is the best tv if you are getting it in 10-...
# 48    Sound quality,Very nice,Value for money,Good,G...
# 49    Sound quality,Very nice,Value for money,Good,G...
# ...                                                 ...
# 1284  Definitely good but wire is too short,Never ex...
# 1285  Super product,Worst antenna.... It came out wh...
# 1286  Quite Good,good pencil,Value for money,Brillia...
# 1287  Quite Good,good pencil,Value for money,Brillia...
# 1293  Good Handy Bluetooth Speaker,Very Nice,Medium,...
#
#                                          review_content  \
# 32    I am using it for 14 days now. The experience ...
# 33    I am using it for 14 days now. The experience ...
# 43    Pros- xiomi 5a is best in budget-Nice picture ...
# 48    LG was always Good , correct delivery, good se...
# 49    LG was always Good , correct delivery, good se...
# ...                                                 ...
# 1284  Product is good. It's definitely a peace for e...
# 1285  Super product,Worst product,Too good product,G...
# 1286  After 10 days of use bhaut acha chl rha ha and...
# 1287  After 10 days of use bhaut acha chl rha ha and...
# 1293  Good Bass and Treble. Good Sound Quality.,Good...
#
#                     order_timestamp  \
# 32    2023-01-03 23:36:23.606557377
# 33    2023-01-03 23:36:23.606557377
# 43    2023-01-04 23:28:31.475409836
# 48    2023-01-05 17:22:37.377049180
# 49    2023-01-05 17:22:37.377049180
# ...                             ...
# 1284  2023-09-10 08:43:16.721311476
# 1285  2023-09-10 14:41:18.688524588
# 1286  2023-09-10 20:39:20.655737704
# 1287  2023-09-10 20:39:20.655737704
# 1293  2023-09-11 20:31:28.524590164
#
#                                            product_name     category  \
# 32    AmazonBasics Flexible Premium HDMI Cable (Blac...  Electronics
# 33    AmazonBasics Flexible Premium HDMI Cable (Blac...  Electronics
# 43    MI 80 cm (32 inches) 5A Series HD Ready Smart ...  Electronics
# 48    LG 80 cm (32 inches) HD Ready Smart LED TV 32L...  Electronics
# 49    LG 80 cm (32 inches) HD Ready Smart LED TV 32L...  Electronics
# ...                                                 ...          ...
# 1284  boAt BassHeads 900 On-Ear Wired Headphones wit...  Electronics
# 1285  Zebronics Astra 10 Portable Wireless BT v5.0 S...  Electronics
# 1286  KINGONE Wireless Charging Pencil (2nd Generati...  Electronics
# 1287  KINGONE Wireless Charging Pencil (2nd Generati...  Electronics
# 1293  Infinity (JBL Fuze 100, Wireless Portable Blue...  Electronics
#
#       discounted_price  ...  rating_filled  category_filled  \
# 32               219.0  ...            4.4      Electronics
# 33               219.0  ...            4.4      Electronics
# 43             13999.0  ...            4.2      Electronics
# 48             13490.0  ...            4.3      Electronics
# 49             13490.0  ...            4.3      Electronics
# ...                ...  ...            ...              ...
# 1284             849.0  ...            4.2      Electronics
# 1285             799.0  ...            3.7      Electronics
# 1286            2599.0  ...            4.5      Electronics
# 1287            2599.0  ...            4.5      Electronics
# 1293            1499.0  ...            4.1      Electronics
#
#       calculated_discount_filled contains_durable product_qid week_number  \
# 32                     68.714286            False  1672909124           1
# 33                     68.714286            False  1672903000           1
# 43                     44.001760            False  1672909124           1
# 48                     38.653934            False  1672909124           1
# 49                     38.653934            False  1672903001           1
# ...                          ...              ...         ...         ...
# 1284                   65.903614            False  1672903019          36
# 1285                   60.030015            False  1672903019          36
# 1286                   62.866124            False  1672895894          36
# 1287                   62.866124            False  1672903019          36
# 1293                   50.016672             True  1672903019          37
#
#        day_name  year month      month_year
# 32      Tuesday  2023     1    January 2023
# 33      Tuesday  2023     1    January 2023
# 43    Wednesday  2023     1    January 2023
# 48     Thursday  2023     1    January 2023
# 49     Thursday  2023     1    January 2023
# ...         ...   ...   ...             ...
# 1284     Sunday  2023     9  September 2023
# 1285     Sunday  2023     9  September 2023
# 1286     Sunday  2023     9  September 2023
# 1287     Sunday  2023     9  September 2023
# 1293     Monday  2023     9  September 2023
#
# [597 rows x 30 columns]

# %%
plt.figure(figsize=(12, 9))
#plt.scatter(df1['discounted_price'],df1['actual_price'])
sns.scatterplot(data=df1, x='discounted_price', y='actual_price', hue="category")
#plt.plot([10000,20000],[40000,50000])
# Out:
# <Axes: xlabel='discounted_price', ylabel='actual_price'>

# %%
df[['month_year','rating_filled']]
# Out:
#          month_year  rating_filled
# 0      January 2023            4.2
# 1      January 2023            4.2
# 2      January 2023            4.2
# 3      January 2023            4.0
# 4      January 2023            4.0
# ...             ...            ...
# 1732  December 2023            4.0
# 1733  December 2023            4.1
# 1734  December 2023            3.6
# 1735  December 2023            4.0
# 1736  December 2023            4.3
#
# [1737 rows x 2 columns]

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# A scatter plot between discounted price and product rating helps Amazon understand the relationship between pricing and customer satisfaction:
#
# - If higher-priced products consistently receive high ratings, it indicates value perception aligns with price, reinforcing premium positioning strategies.
#
# - Clusters of lower-priced products with high ratings suggest good value-for-money products, which can be promoted to attract budget-conscious customers.
#
# - Outliers (e.g., expensive products with low ratings) signal potential quality or expectation issues, prompting product review audits or quality checks.
#
# - Observing that most ratings cluster around 4–5 regardless of price can guide review incentivization strategies for high-end products to boost credibility and encourage purchases.
#
# ## <span style=color:skyblue>Visualization Goal: Line Plot</span>
# A line plot often represents data over time. Let’s plot the average rating filled by month and year to see trends.
#
# ### Key Insights
# * Observe how ratings change month to month.
# * Could highlight seasonal spikes or dips.

# %%
df[['month_year','rating_filled']]
# Out:
#          month_year  rating_filled
# 0      January 2023            4.2
# 1      January 2023            4.2
# 2      January 2023            4.2
# 3      January 2023            4.0
# 4      January 2023            4.0
# ...             ...            ...
# 1732  December 2023            4.0
# 1733  December 2023            4.1
# 1734  December 2023            3.6
# 1735  December 2023            4.0
# 1736  December 2023            4.3
#
# [1737 rows x 2 columns]

# %%
monthly_rating = df.groupby('month_year')['rating_filled'].mean()
monthly_rating
# Out:
# month_year
# April 2023        4.117893
# August 2023       4.150808
# December 2023     3.997620
# February 2023     4.107133
# January 2023      4.144502
# July 2023         4.168792
# June 2023         4.135401
# March 2023        4.102346
# May 2023          4.091215
# November 2023     4.035636
# October 2023      4.070448
# September 2023    4.093328
# Name: rating_filled, dtype: float64

# %%
monthly_rating.index
# Out:
# Index(['April 2023', 'August 2023', 'December 2023', 'February 2023',
#        'January 2023', 'July 2023', 'June 2023', 'March 2023', 'May 2023',
#        'November 2023', 'October 2023', 'September 2023'],
#       dtype='object', name='month_year')

# %%
monthly_rating.reset_index()
# Out:
#         month_year  rating_filled
# 0       April 2023       4.117893
# 1      August 2023       4.150808
# 2    December 2023       3.997620
# 3    February 2023       4.107133
# 4     January 2023       4.144502
# 5        July 2023       4.168792
# 6        June 2023       4.135401
# 7       March 2023       4.102346
# 8         May 2023       4.091215
# 9    November 2023       4.035636
# 10    October 2023       4.070448
# 11  September 2023       4.093328

# %%
monthly_rating = monthly_rating.reset_index()
monthly_rating
# Out:
#         month_year  rating_filled
# 0       April 2023       4.117893
# 1      August 2023       4.150808
# 2    December 2023       3.997620
# 3    February 2023       4.107133
# 4     January 2023       4.144502
# 5        July 2023       4.168792
# 6        June 2023       4.135401
# 7       March 2023       4.102346
# 8         May 2023       4.091215
# 9    November 2023       4.035636
# 10    October 2023       4.070448
# 11  September 2023       4.093328

# %%
monthly_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   month_year     12 non-null     object
#  1   rating_filled  12 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 324.0+ bytes

# %%
pd.to_datetime(monthly_rating['month_year'],format="%B %Y")
# Out:
# 0    2023-04-01
# 1    2023-08-01
# 2    2023-12-01
# 3    2023-02-01
# 4    2023-01-01
# 5    2023-07-01
# 6    2023-06-01
# 7    2023-03-01
# 8    2023-05-01
# 9    2023-11-01
# 10   2023-10-01
# 11   2023-09-01
# Name: month_year, dtype: datetime64[ns]

# %%
pd.to_datetime(monthly_rating['month_year'])
# Out:
# /tmp/ipython-input-1873891048.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(monthly_rating['month_year'])
# 0    2023-04-01
# 1    2023-08-01
# 2    2023-12-01
# 3    2023-02-01
# 4    2023-01-01
# 5    2023-07-01
# 6    2023-06-01
# 7    2023-03-01
# 8    2023-05-01
# 9    2023-11-01
# 10   2023-10-01
# 11   2023-09-01
# Name: month_year, dtype: datetime64[ns]

# %% [markdown]
# We can use the datetime methods
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/166/412/original/Screenshot_2025-11-19_202417.png?1763564065" width="300" />

# %%
monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')
monthly_rating
# Out:
#    month_year  rating_filled
# 0  2023-04-01       4.117893
# 1  2023-08-01       4.150808
# 2  2023-12-01       3.997620
# 3  2023-02-01       4.107133
# 4  2023-01-01       4.144502
# 5  2023-07-01       4.168792
# 6  2023-06-01       4.135401
# 7  2023-03-01       4.102346
# 8  2023-05-01       4.091215
# 9  2023-11-01       4.035636
# 10 2023-10-01       4.070448
# 11 2023-09-01       4.093328

# %%
# Sort the DataFrame based on 'month_year.'
monthly_rating = monthly_rating.sort_values('month_year')
monthly_rating
# Out:
#    month_year  rating_filled
# 4  2023-01-01       4.144502
# 3  2023-02-01       4.107133
# 7  2023-03-01       4.102346
# 0  2023-04-01       4.117893
# 8  2023-05-01       4.091215
# 6  2023-06-01       4.135401
# 5  2023-07-01       4.168792
# 1  2023-08-01       4.150808
# 11 2023-09-01       4.093328
# 10 2023-10-01       4.070448
# 9  2023-11-01       4.035636
# 2  2023-12-01       3.997620

# %%
monthly_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 4 to 2
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   month_year     12 non-null     datetime64[ns]
#  1   rating_filled  12 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 288.0 bytes

# %%
monthly_rating["month_year"].dt.day
# Out:
# 4     1
# 3     1
# 7     1
# 0     1
# 8     1
# 6     1
# 5     1
# 1     1
# 11    1
# 10    1
# 9     1
# 2     1
# Name: month_year, dtype: int32

# %%
monthly_rating
# Out:
#    month_year  rating_filled
# 4  2023-01-01       4.144502
# 3  2023-02-01       4.107133
# 7  2023-03-01       4.102346
# 0  2023-04-01       4.117893
# 8  2023-05-01       4.091215
# 6  2023-06-01       4.135401
# 5  2023-07-01       4.168792
# 1  2023-08-01       4.150808
# 11 2023-09-01       4.093328
# 10 2023-10-01       4.070448
# 9  2023-11-01       4.035636
# 2  2023-12-01       3.997620

# %%
monthly_rating['month_year'].dt.strftime('%B %Y')
# Out:
# 4       January 2023
# 3      February 2023
# 7         March 2023
# 0         April 2023
# 8           May 2023
# 6          June 2023
# 5          July 2023
# 1        August 2023
# 11    September 2023
# 10      October 2023
# 9      November 2023
# 2      December 2023
# Name: month_year, dtype: object

# %% [markdown]
# ### <span style= color:violet>How has customer satisfaction, as measured by average product ratings, changed month by month?</span>

# %%
monthly_rating['month_year'] = monthly_rating['month_year'].dt.strftime('%B %Y')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'month_year' and calculate average rating
monthly_rating = df.groupby('month_year')['rating_filled'].mean().reset_index()

# Ensure 'month_year' is in datetime format
#sept - b
#September
monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')

# Sort the DataFrame based on 'month_year.'
monthly_rating = monthly_rating.sort_values('month_year')

# Convert back to string for proper x-axis labels
monthly_rating['month_year'] = monthly_rating['month_year'].dt.strftime('%B %Y')

# Plot
plt.figure(figsize=(10, 6))
plt.plot(monthly_rating['month_year'], monthly_rating['rating_filled'], marker='o', color='navy')

# Rotate the x-axis labels and add a grid
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
#plt.grid(linestyle='--', alpha=0.7)

plt.title("Average Rating by Month-Year", fontsize=16)
plt.xlabel("Month-Year", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Note:** Notice the following line of code:
#
# ```python
# monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')
# ```
#
# We convert `monthly_rating['month_year']` to a `datetime` type so that the data can be sorted in chronological (increasing month-wise) order. This ensures that the monthly ratings are analyzed in the correct sequence over time.
#
# The format `'%B %Y'` is used so that the data is in the form of full month name followed by the year (e.g., *January 2023*), where:
#
# * `%B` represents the full month name
# * `%Y` represents the four-digit year

# %%
# Group by 'month_year' and calculate average rating
monthly_rating = df.groupby('month_year')['rating_filled'].mean().reset_index()

# Ensure 'month_year' is in datetime format
#sept - b
#September
monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')

# Sort the DataFrame based on 'month_year.'
monthly_rating = monthly_rating.sort_values('month_year')

# Convert back to string for proper x-axis labels
monthly_rating['month_year'] = monthly_rating['month_year'].dt.strftime('%B %Y')

# Plot
plt.figure(figsize=(10, 6))
plt.plot(monthly_rating['month_year'], monthly_rating['rating_filled'], marker='o', color='navy')

# Rotate the x-axis labels
plt.xticks(rotation=45)
plt.grid(False)
plt.tight_layout()#"Please adjust margins so everything fits neatly within the figure."

# %% [markdown]
# **Instructor Note:** Only change in this graph and above one is we have set the `plt.grid(False)` to remove the grid lines.

# %%
# Group by 'month_year' and calculate average rating
monthly_rating = df.groupby('month_year')['rating_filled'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(monthly_rating['month_year'], monthly_rating['rating_filled'], marker='o', color='navy')

# Styling Tip
# Rotate the x-axis labels and add a grid
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

plt.title("Average Rating by Month-Year", fontsize=16)
plt.xlabel("Month-Year", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Instructor Note:** This is how the output would look if we do not convert the `month_year` column to `datetime` format.

# %% [markdown]
# <span style="background-color: red;color: White;">Note:</span> You can use Seaborn’s lineplot:

# %%
sns.lineplot(data=monthly_rating, x='month_year', y='rating_filled', marker='o', color='navy')
plt.xticks(rotation=45)
plt.title("Average Rating by Month-Year")
plt.xlabel("Month-Year")
plt.ylabel("Average Rating")
plt.show()

# %%
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
# Out:
# <BarContainer object of 12 artists>

# %%
# Group by 'month_year' and calculate average rating
monthly_rating = df.groupby('month_year')['rating_filled'].mean().reset_index()

# Convert to datetime for proper sorting
monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')

# Sort by month-year
monthly_rating = monthly_rating.sort_values('month_year')

# Convert back to string for x-axis labels
monthly_rating['month_year'] = monthly_rating['month_year'].dt.strftime('%B %Y')

# Bar Plot
plt.figure(figsize=(10, 6))
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')

plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

plt.title("Average Rating by Month-Year", fontsize=16)
plt.xlabel("Month-Year", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# A line plot of average product ratings by month-year provides Amazon with insights into temporal trends in customer satisfaction:
#
# - Seasonal patterns: Ratings may spike during festive seasons or sales events (e.g., Prime Day, Diwali, Black Friday) when high-demand products perform well.
#
# - Trend analysis: Identifying upward or downward trends in average ratings helps monitor overall customer sentiment over time.
#
# - Product quality monitoring: Sudden drops in average ratings could indicate product issues, shipment problems, or quality dips.
#
# - Impact of interventions: Tracking ratings over time allows Amazon to measure the effect of marketing campaigns, price changes, or product launches on customer satisfaction.
#
#
# ## <span style=color:skyblue>Visualization Goal: Box Plot</span>
# A box plot shows the distribution of a numerical variable across different categories. Let’s examine the rating by category.
#
# ### Key Insights
# * Spot differences in median rating by category.
# * Identify potential outliers within each category.
#
# Imagine I have a class of students with the following ages:
# - 25, 23, 45, 34, 21, 23, 26, 67, 89
#
# After sorting,
# - 21, 23, 23, 25, 26, 34, 45, 67, 89
#
# Middle value: 26 (50th percentile):
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/166/425/original/Screenshot_2025-11-19_210236.png?1763566362" width="500" />
#
# In simple terms,
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/166/426/original/Screenshot_2025-11-19_210335.png?1763566422" width="500" />

# %%
plt.boxplot(df['rating_filled'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ed8313f8b90>,
#   <matplotlib.lines.Line2D at 0x7ed8313f8ec0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ed8313f9190>,
#   <matplotlib.lines.Line2D at 0x7ed8313f9460>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ed8313f85c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ed8313f9790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ed8313d0aa0>],
#  'means': []}

# %% [markdown]
# ### <span style=color:violet> How does customer satisfaction, measured by product ratings, vary across different product categories on Amazon, and which categories show the most inconsistencies or outliers?</span>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip 💡 palette

plt.xticks(rotation=45)
plt.title("Rating Distribution by Category", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-958117089.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip 💡 palette

# %% [markdown]
# - Home & Kitchen has a wider spread with several low-rated products, indicating possible quality inconsistencies.
# - Musical Instruments has the lowest median rating, suggesting customer dissatisfaction or unmet expectations.
# - this shows we can have some new market opportunities over here in these cattegories like home and musical
#
#
# ### <span style=color:orange> Business Context:</span>
#
# A box plot of product ratings by category allows Amazon to understand category-level customer satisfaction and product quality trends:
#
# - Median and spread: Categories with high median ratings (e.g., Electronics) indicate consistent customer satisfaction, while a wider spread (e.g., Home & Kitchen) reveals inconsistencies in product quality.
#
# - Outliers: Low-rated products within a category can signal quality issues, misleading descriptions, or customer service problems.
#
# - Category comparison: Categories like Musical Instruments showing lower median ratings may highlight unmet customer expectations, providing insights for product improvement, targeted reviews, or quality checks.
#
# - Market opportunities: Identifying categories with high variability or low ratings helps Amazon explore new product offerings, quality enhancements, or niche opportunities to capture more market share.
#
# <span style="background-color: red;color: White;">Note:</span> Matplotlib has plt.boxplot, for similar plot
#
#
#
# ## <span style=color:skyblue>Visualization Goal: Violin Plot</span>
#
# A violin plot is similar to a box plot but also shows the kernel density of the data. Let’s see the distribution of `discounted_price` by `rating_category`.
#
# ### Key Insights
# * Compare the spread of prices for different rating categories.
# * Check if there's a concentration of lower/higher prices in certain categories.

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='rating_category', y='discounted_price', inner='quartile', palette='Accent')

plt.title("Violin Plot of Discounted Price by Rating Category", fontsize=16)
plt.xlabel("Rating Category", fontsize=12)
plt.ylabel("Discounted Price", fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-3856105535.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='rating_category', y='discounted_price', inner='quartile', palette='Accent')

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# A violin plot of discounted prices by rating category helps Amazon analyze the relationship between product pricing and customer-perceived value:
#
# - Price distribution insights: The plot reveals how prices vary within each rating category, showing whether highly rated products tend to be more expensive or if lower-rated products are concentrated in certain price ranges.
#
# - Identify pricing patterns: Concentrations of lower-priced products in high-rating categories suggest good value-for-money items, while high-priced products with low ratings indicate potential overpricing or quality issues.
#
# - Strategic decisions: These insights guide pricing strategies, promotional planning, and inventory allocation, ensuring that products are competitively priced while maintaining high customer satisfaction.
#
# - Opportunity identification: Categories with wide spreads in discounted prices and varying ratings may represent opportunities for new product introductions, discount optimization, or premium positioning.
#
# ## <span style=color:skyblue>Visualization Goal: Grouped Bar Plot</span>
# A grouped bar plot compares multiple categories side by side. Let’s compare the average `rating` for products that do or do not contain the keyword "durable", across different `rating_category`.
#
# ### Key Insights
# * Check how “durable” items perform in each rating category vs. non-durable.
# * Identify which group has higher/lower average ratings.

# %%
# Create a pivoted dataframe
grouped_data = df.groupby(['rating_category', 'contains_durable'])['rating_filled'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=grouped_data, x='rating_category', y='rating_filled', hue='contains_durable', palette='Paired')

# Styling Tip 💡
# Add legend title
plt.legend(title='Contains Durable?')

plt.title("Average Rating by Rating Category and Durability", fontsize=16)
plt.xlabel("Rating Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.show()

# %% [markdown]
# - since durable products tend to receive higher ratings, highlight durability features in product descriptions and marketing campaigns.
# - The "Poor" category consists only of non-durable products, reinforcing that low-quality, short-lived products tend to receive more negative feedback.
#
# ### <span style=color:orange> Business Context:</span>
#
# A grouped bar plot comparing average ratings of durable vs. non-durable products across rating categories provides Amazon with insights into how product characteristics influence customer satisfaction:
#
# - Durability impact: Products labeled as “durable” generally receive higher ratings, indicating that longevity and quality are key drivers of customer satisfaction.
#
# - Category-specific insights: Observing that the “Poor” rating category only contains non-durable products reinforces the connection between product quality and negative reviews.
#
# - Marketing and product strategy: Insights from this visualization can guide product descriptions, feature highlighting, and promotional campaigns to emphasize durability, especially for mid- to high-priced products.
#
# - Inventory and sourcing decisions: Understanding which features correlate with higher ratings helps in sourcing high-quality products, optimizing category offerings, and reducing returns or complaints.
#
# ---
#
# # Question
# In a scatter plot of Hours Studied vs Exam Scores, the points curve upward but correlation is $≈ 0$. Which conclusion is correct?
#
# # Choices
# - [ ] No relationship exists between study hours and scores.
# - [x] A strong nonlinear relationship exists.
# - [ ] Correlation was calculated incorrectly.
# - [ ] Outliers destroyed the correlation completely.
#
#
# Explanation: Pearson correlation misses nonlinear trends. A curved upward pattern = nonlinear relationship.
#
# ---
# # Multivariate Plots (Three or More Variables)
#
#
# ## Visualization Goal: Pair Plot
# A pair plot visualizes pairwise relationships and distributions for multiple numerical variables. Let’s look at `rating`, `discounted_price`, and `actual_price`.
#
# ### Key Insights
# * Quickly spot correlations.
# * View distributions on the diagonal.

# %%
df.loc[df['category']=="Car&Motorbike"]
# Out:
#       product_id                                            user_id  \
# 1429  B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
#
#                                               user_name  \
# 1429  Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
#
#                                               review_id  \
# 1429  R3TOOFPX256D59,R1PR50BDQOEIIO,R392FI4QWXWOX5,R...
#
#                                            review_title  \
# 1429  Liked it,User friendly and effective,Not as pe...
#
#                                          review_content  \
# 1429  As of now its working fine, but don't expect m...
#
#                     order_timestamp  \
# 1429  2023-10-15 16:03:56.065573772
#
#                                            product_name       category  \
# 1429  Reffair AX30 [MAX] Portable Air Purifier for C...  Car&Motorbike
#
#       discounted_price  ...  rating_filled  category_filled  \
# 1429            2339.0  ...            3.8    Car&Motorbike
#
#       calculated_discount_filled contains_durable product_qid week_number  \
# 1429                      41.525            False  1672923598          41
#
#      day_name  year month    month_year
# 1429   Sunday  2023    10  October 2023
#
# [1 rows x 30 columns]

# %% [markdown]
# Numerical(continuous) - Histogram creates bins and counts the values.
#
# cat - countplot - barplot - Mobile-count
#
# Bar - category - count the values
# Bar - category, count, mean, median, max
#
# scatter - num num - Relationship between 2 num columns
#
# line plot -Trend Date and Num(Trend)
#
# box - cat vs num
# box - num
#
#
#
# histogram: bins and count,
# bar: category and frequency, cat, median, cat and mean
#
# Count: category and count of them.

# %%
sns.pairplot(data=df[['discounted_price', 'actual_price', 'calculated_discount_filled', 'rating_filled']])

# %%
sns.pairplot(df[['rating', 'discounted_price', 'actual_price', 'calculated_discount_filled']].dropna(),
             diag_kind='kde', corner=True, plot_kws={'alpha':0.5})
plt.show()

# %% [markdown]
# - notice the actual price and discounted price plots. we can assume that discounts are applied proportionally to the original price rather than randomly.
# - scatter between calculated_discount_filled and rating does not show a clear upward trend.
# - Mid-range products (₹10,000 - ₹30,000) tend to have higher discounts than extremely high-end or low-priced products.
#
# ### <span style=color:orange> Business Context:</span>
#
# A pair plot provides Amazon with a comprehensive view of relationships among multiple numerical variables, helping inform pricing, discounting, and product strategy:
#
# - Discount patterns: Observing that discounts are applied proportionally to actual prices confirms that pricing strategies are systematic rather than random.
#
# - Pricing vs. ratings: Lack of a clear correlation between discounts and ratings suggests that higher discounts do not necessarily drive higher customer satisfaction, indicating other factors (like quality or brand) influence ratings more.
#
# - Mid-range focus: Products in the mid-price range (₹10,000–₹30,000) receive higher discounts, highlighting a strategy to stimulate sales in this segment while maintaining margins on low- and high-end products.
#
# - Strategic insights: Understanding these relationships helps in optimizing pricing, discounting strategies, and promotions, as well as identifying product segments where pricing adjustments could improve customer satisfaction and sales.
#
# ## Visualization Goal: Heatmap
# A heatmap is great for correlation matrices. Let’s see how `rating`, `discounted_price`, `actual_price`, `rating_count`, etc., correlate.
#
# ### Key Insights
# * Identify strong positive or negative correlations.
# * Guides feature selection or further analysis.

# %%
corr_cols = ['rating', 'discounted_price', 'actual_price', 'rating_count', 'calculated_discount']
corr_matrix = df[corr_cols].corr()
corr_matrix
# Out:
#                        rating  discounted_price  actual_price  rating_count  \
# rating               1.000000          0.102694      0.107082      0.108127
# discounted_price     0.102694          1.000000      0.961261     -0.027870
# actual_price         0.107082          0.961261      1.000000     -0.037288
# rating_count         0.108127         -0.027870     -0.037288      1.000000
# calculated_discount -0.146924         -0.251724     -0.128962      0.014303
#
#                      calculated_discount
# rating                         -0.146924
# discounted_price               -0.251724
# actual_price                   -0.128962
# rating_count                    0.014303
# calculated_discount             1.000000

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
corr_cols = ['rating', 'discounted_price', 'actual_price', 'rating_count', 'calculated_discount']
corr_matrix = df[corr_cols].corr()

plt.figure(figsize=(8, 6))

# Styling Tip
# Format annotation to 2 decimal places
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='Blues')

plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %% [markdown]
# - again discounted prices are directly proportional to actual prices, meaning discounts are percentage-based rather than fixed amounts.
# - Rating vs. Discounted Price (0.10) and Rating vs. Actual Price (0.11) show almost no correlation, meaning higher-priced products do not necessarily get better ratings.
# - Since high discounts do not lead to better ratings, businesses should prioritize improving product quality and customer service rather than relying on heavy discounts.
# - Since expensive products do not necessarily get higher ratings, consider adding value through better warranties, customer support, and post-purchase engagement to boost satisfaction.

# %%
sns.heatmap(corr_matrix,annot=True,fmt=".2f",cmap="flare")
# Out:
# <Axes: >

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'berlin_r', 'managua_r', 'vanimo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r', 'grey_r', 'gist_grey_r', 'gist_yerg_r', 'Grays_r', 'rocket', 'rocket_r', 'mako', 'mako_r', 'icefire', 'icefire_r', 'vlag', 'vlag_r', 'flare', 'flare_r', 'crest', 'crest_r']

# %%
sns.palplot(sns.color_palette("flare"))

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# A correlation heatmap helps Amazon understand how numerical variables interact, providing insights into pricing strategies, customer satisfaction, and business priorities:
#
# - Discount vs. actual price: The strong positive correlation confirms that discounts are applied as a percentage of the original price, indicating a consistent pricing strategy.
#
# - Price vs. rating: Weak correlations between rating and discounted or actual price suggest that higher prices do not guarantee higher customer satisfaction, highlighting the importance of product quality and customer experience over pricing alone.
#
# - Discount vs. rating: Minimal correlation indicates that offering higher discounts does not necessarily improve ratings, emphasizing that Amazon should focus on enhancing product features, warranties, and post-purchase support rather than relying solely on discounts to drive satisfaction.
#
# - Strategic implications: These insights guide pricing policies, product development, and customer engagement strategies, ensuring that efforts to increase sales do not compromise long-term customer satisfaction.
#
#
# ## Subplots and hue
# The `hue` parameter in **Seaborn** allows us to color the data points (or bars, lines, etc.) by another categorical variable, giving a quick comparison without creating separate subplots or separate figures.
#
# **Example: Bar Plot with Hue**
#
# Let’s say we want to compare the **average rating** by `rating_category` for products that **do or do not contain “durable”**. We'll use the `contains_durable` column as the `hue` parameter.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Group by rating_category and contains_durable, then compute average rating
grouped_data = df.groupby(['rating_category', 'contains_durable'])['rating_filled'].mean().reset_index()

sns. barplot(
    data=grouped_data,
    x='rating_category',
    y='rating_filled',
    hue='contains_durable',
    palette='viridis'
)

# Styling Tip 💡
# Add a legend title and rotate x-axis labels
plt.legend(title='Durable?')
plt.xticks(rotation=45)
plt.title("Average Rating by Rating Category and Durability", fontsize=16)
plt.xlabel("Rating Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.show()

# %%
grouped_data = df.groupby(['category','contains_durable'])['rating_filled'].mean().reset_index()
grouped_data
# Out:
#                  category  contains_durable  rating_filled
# 0           Car&Motorbike             False       3.800000
# 1   Computers&Accessories             False       4.164646
# 2   Computers&Accessories              True       4.148962
# 3             Electronics             False       4.085581
# 4             Electronics              True       4.128571
# 5     Health&PersonalCare             False       4.000000
# 6            Home&Kitchen             False       4.059434
# 7            Home&Kitchen              True       3.941667
# 8         HomeImprovement             False       4.250000
# 9      MusicalInstruments             False       3.900000
# 10         OfficeProducts             False       4.309677
# 11             Toys&Games             False       4.300000

# %%
sns.barplot(data=grouped_data, x='category', y='rating_filled')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data=grouped_data, x='category', y='rating_filled', hue='contains_durable')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# Using the hue parameter allows Amazon to analyze multiple dimensions simultaneously, providing richer insights without creating separate charts:
#
# - Durability impact: By coloring bars based on whether products are labeled as “durable,” we can see how durable products perform compared to non-durable ones within each rating category.
#
# - Customer satisfaction insights: This helps identify product features that drive higher ratings, highlighting that durable products generally receive better feedback.
#
# - Marketing and positioning: Insights from this visualization can inform marketing campaigns, product descriptions, and feature promotion, emphasizing durability to boost customer trust and sales.
#
# - Operational strategy: Categories with low-rated non-durable products can be targeted for quality improvements, better materials, or supplier evaluation.
#
# ### Subplots with Different Hues
#
# Sometimes, you may want multiple subplots side by side, each using a different hue variable. This can be useful if you have multiple categorical variables you want to highlight in separate views.
#
# **Example:** Two Scatter Plots with Different Hues
#
# * In the first subplot, we'll color by `rating_category`.
# * In the second subplot, we’ll color by the `price_range` column (imagine it categorizes items as “Budget”, “Mid-range”, “Premium”, etc.).

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Subplot 1: Hue by 'rating_category.'
sns. scatterplot(
    data=df,
    x='discounted_price',
    y='rating_filled',
    hue='rating_category',
    ax=axes[0],
    palette='coolwarm'
)
axes[0].set_title("Discounted Price vs. Rating (Hue: Rating Category)", fontsize=14)
axes[0].set_xlabel("Discounted Price", fontsize=12)
axes[0].set_ylabel("Rating", fontsize=12)

# Subplot 2: Hue by 'price_range.'
sns. scatterplot(
    data=df,
    x='discounted_price',
    y='rating_filled',
    hue='price_range',  # Alternatively: 'actual_price', binned, or another categorical col
    ax=axes[1],
    palette='Spectral'
)
axes[1].set_title("Discounted Price vs. Rating (Hue: Price Range)", fontsize=14)
axes[1].set_xlabel("Discounted Price", fontsize=12)
axes[1].set_ylabel("Rating", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - low-priced products have both high and low ratings, indicating inconsistent quality.
# - should invest in quality assurance and ensure consistency in product descriptions and expectations.

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,3,1)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)
plt.tight_layout()


plt.subplot(2,3,2)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)


plt.subplot(2,3,3)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)

plt.subplot(2,3,4)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)


plt.subplot(2,3,5)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)

plt.subplot(2,3,6)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)

plt.show()
# Out:
# /tmp/ipython-input-388824672.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
# /tmp/ipython-input-388824672.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
# /tmp/ipython-input-388824672.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette

# %%
plt.figure(figsize=(14,9))
plt.subplot(2,3,1)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)


plt.subplot(2,3,2)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)


plt.subplot(2,3,3)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)

plt.subplot(2,3,4)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)


plt.subplot(2,3,5)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)

plt.subplot(2,3,6)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)

plt.show()
# Out:
# /tmp/ipython-input-2283118445.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
# /tmp/ipython-input-2283118445.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
# /tmp/ipython-input-2283118445.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette

# %%
plt.figure(figsize=(16,14))
plt.subplot(2,3,1)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)
plt.tight_layout()


plt.subplot(2,3,2)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)


plt.subplot(2,3,5)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)

plt.subplot(2,3,6)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)

plt.show()
# Out:
# /tmp/ipython-input-1305414016.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
# /tmp/ipython-input-1305414016.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette
plt.xticks(rotation=90)

plt.subplot(1,2,2)
plt.bar(monthly_rating['month_year'], monthly_rating['rating_filled'], color='skyblue')
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# /tmp/ipython-input-4046999453.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip palette

# %% [markdown]
# ### <span style=color:orange> Business Context:</span>
#
# Using multiple subplots with different hues allows Amazon to compare the same relationship across different categorical dimensions, providing deeper insights into product performance and pricing strategies:
#
# - Rating category insights: Coloring by rating_category helps identify how products in different satisfaction tiers perform across price points, revealing clusters of low-rated or high-rated items.
#
# - Price range insights: Coloring by price_range highlights whether budget, mid-range, or premium products achieve higher ratings, exposing potential quality or value inconsistencies.
#
# - Operational implications: Observing that low-priced products have both high and low ratings signals the need for better quality control, accurate product descriptions, and expectation management.
#
# - Strategic actions: These insights inform product sourcing, quality assurance, marketing messaging, and pricing strategies to enhance customer satisfaction and reduce returns or complaints.
#
# ## Stacked Plots
# A stacked plot (most commonly a stacked bar plot) allows you to see parts of a whole for different categories on top of each other.
#
# 1 Stacked **Bar Plot** Let’s say we want to visualize how rating_category is distributed within each `price_range` category. This will show each price range on the x-axis and “stack” the segments of rating categories in each bar.
#
# **Steps:**
#
# * Compute counts of reviews (or any metric) grouped by price_range and rating_category.
# * Unstack the grouped data so each rating_category becomes a separate column.
# * Use Matplotlib (pandas plotting) with stacked=True.

# %%
# 1. Group by price_range and rating_category, and get counts
grouped_stack = df.groupby(['price_range', 'rating_category'])['review_id'].count().unstack()

# 2. Plot as a stacked bar
grouped_stack.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    colormap='Blues'
)

# Styling Tip
plt.title("Stacked Bar Plot: Rating Categories by Price Range", fontsize=16)
plt.xlabel("Price Range", fontsize=12)
plt.ylabel("Number of Reviews", fontsize=12)
plt.legend(title="Rating Category")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Encourage More Reviews for High & Very High-Priced Products
# - identify patterns in negative reviews of low-priced products and address recurring complaints to reduce refund rates and improve trust.
#
# <span style="background-color: red;color: White;">Note:</span> A stacked bar plot can become hard to read if there are many categories. In such cases, a grouped bar chart or a different type of visualization might be more suitable.
#
# ### <span style=color:orange> Business Context:</span>
#
# A stacked bar plot showing the distribution of rating categories within each price range provides Amazon with insights into customer satisfaction patterns across different pricing segments:
#
# - Review distribution: By visualizing how “Poor,” “Average,” and “Excellent” ratings stack within budget, mid-range, and premium products, Amazon can identify which price segments receive more negative or positive feedback.
#
# - High-priced products: Encouraging reviews for high and very high-priced products can increase credibility and assist customers in making informed purchase decisions.
#
# - Low-priced products: Identifying patterns of negative reviews in budget products highlights quality issues or recurring complaints, guiding product improvements, supplier evaluation, or description enhancements to reduce refunds and boost trust.
#
# - Strategic decision-making: This visualization helps category managers, quality assurance teams, and marketing strategists to optimize product offerings, pricing strategies, and customer engagement efforts.
#
# ## Conclusion
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/166/464/original/Screenshot_2024-12-27_103544.png?1763572840" width="900" />
#
#
# Visualization is about **asking the right question** and **picking the right plot** for both your **data** and your **audience**. We’ve covered a range of plots—univariate, bivariate, and multivariate—and explored how to add extra dimensions via **hue**, **subplots**, and **stacked** techniques.
#
# - **Focus on the story** you want to tell; each plot should highlight a key insight or pattern.
# - **Keep it simple**: avoid clutter, label axes clearly, and use color thoughtfully.
# - **Know your audience**: are they familiar with complex plots, or do they prefer simpler visualizations?
# - **Iterate**: no single plot is perfect; try multiple approaches to see what communicates insights best.
#
# **Remember**: A plot is only as powerful as the **question** it helps answer. Combine clarity, audience awareness, and the right techniques to deliver compelling data stories.
#
# <span style=background-color:red>**Instructor Note:**</span> Open this cheetsheet at the end of the lecture to answer questions, if you have time [link](https://drive.google.com/file/d/1EDV3aiBRzw8zgGD7i0wj3mmCWOt541P4/view)
#
#
# # Question
# Which of the following is NOT a correct interpretation during EDA?
# # Choices
# - [ ] A high standard deviation means values are more spread out.
# - [ ] If mean ≠ median, the distribution might be skewed.
# - [x] If correlation is 0, the variables are independent.
# - [ ] Outliers can significantly affect the mean but less so the median.
#
#
# Explanation: Correlation = 0 means no linear relationship, but variables can still be related nonlinearly.
